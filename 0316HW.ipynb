# %% [markdown]
# <a href="https://colab.research.google.com/github/EG886/big-data/blob/main/0316HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
system("ls",TRUE)
# Out:
# [1] "11003.csv"   "sample_data"

# %%
library(readr)

# %%
dataset <- read.csv("11003.csv")

# %%
dataset
# Out:
#     商號.公司名稱                    統一編號 經營行業
# 1   皇樂舞廳                         10169821 舞廳業
# 2   台南大舞廳                       10806981 舞廳業
# 3   萬象育樂有限公司                 24909208 舞廳業
# 4   夜歡大舞廳                       81554917 舞廳業
# 5   天樂酒家                         71071700 酒家業
# 6   桃源茶室                         73221206 特種咖啡茶室業
# 7   美花園茶室                       71327702 特種咖啡茶室業
# 8   美樂茶室                         74078684 特種咖啡茶室業
# 9   金晶茶坊                               NA 特種咖啡茶室業
# 10  莉芳冷飲店                       47811825 特種咖啡茶室業
# 11  那麼旺茶行                       47788303 特種咖啡茶室業
# 12  綠館三溫暖                       98817392 三溫暖業
# 13  奕植鑽複合式餐廳                 40729934 視聽歌唱業
# 14  美尚美海產                       36824605 視聽歌唱業
# 15  全鴻餐飲店                       62916411 視聽歌唱業
# 16  紅牌視聽歌唱                     14983951 視聽歌唱業
# 17  尚樂小吃店                       36829897 視聽歌唱業
# 18  小上海餐飲                       81407129 視聽歌唱業
# 19  星鑽視聽歌唱                     13207721 視聽歌唱業
# ...

# %%
head(dataset$商號.公司名稱, n=10)
# Out:
#  [1] "皇樂舞廳"         "台南大舞廳"       "萬象育樂有限公司" "夜歡大舞廳"
#  [5] "天樂酒家"         "桃源茶室"         "美花園茶室"       "美樂茶室"
#  [9] "金晶茶坊"         "莉芳冷飲店"

# %%
tail(dataset$商號.公司名稱, n=10)
# Out:
#  [1] "鑫發餐廳"                         "姊妹練歌場"
#  [3] "崴順商行"                         "月娘餐飲店"
#  [5] "無店名"                           "吉宸餐飲店"
#  [7] "美樂地賓士視聽歌唱"               "天上人間視聽歌唱〈羅馬視聽歌唱〉"
#  [9] "白濱冷飲店"                       "好樂迪股份有限公司成功分公司"

# %%
dataset[grepl("特種咖啡茶室業",dataset$經營行業),]
# Out:
#    商號.公司名稱 統一編號 經營行業       營業地址
# 6  桃源茶室      73221206 特種咖啡茶室業 臺南市玉井區玉田里中華路113號
# 7  美花園茶室    71327702 特種咖啡茶室業 臺南市鹽水區水秀里朝琴路113號
# 8  美樂茶室      74078684 特種咖啡茶室業 臺南市學甲區慈福里中山路85號
# 9  金晶茶坊            NA 特種咖啡茶室業 臺南市南區中華南路一段137號
# 10 莉芳冷飲店    47811825 特種咖啡茶室業 臺南市南區大恩里國民路182號1樓
# 11 那麼旺茶行    47788303 特種咖啡茶室業 臺南市北區成德里育成路57號1 、2樓

# %%
table(dataset$經營行業)
# Out:
#       三溫暖業 特種咖啡茶室業     視聽歌唱業         舞廳業         酒家業
#              1              6            241              4              1
