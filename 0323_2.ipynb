# %% [markdown]
# <a href="https://colab.research.google.com/github/EG886/big-data/blob/main/0323_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("SportsAnalytics")
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)
library(ggplot2)

# %%
NBA1920 <-fetch_NBAPlayerStatistics("19-20")
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1920)
# Out:
# plot without title

# %%
qplot(TotalRebounds,TotalPoints,data=NBA1920)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1920,color=Position)
# Out:
# plot without title

# %%
qplot(TotalRebounds,TotalPoints,data=NBA1920,color=Position)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1920,geom=c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(TotalRebounds,TotalPoints,data=NBA1920,geom=c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(TotalPoints,data=NBA1920,fill=Position)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(TotalRebounds,data=NBA1920,fill=Position)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1920,facets=Position~.)
# Out:
# plot without title

# %%
qplot(TotalRebounds,TotalPoints,data=NBA1920,facets=Position~.)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1920,facets=.~Position)
# Out:
# plot without title

# %%
qplot(TotalRebounds,TotalPoints,data=NBA1920,facets=.~Position)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1920,facets=Position~.,binwidth=10)
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth”
# plot without title

# %%
qplot(TotalRebounds,TotalPoints,data=NBA1920,facets=.~Position,binwidth=10)
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth”
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1920,facets=Position~.,binwidth=100)
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth”
# plot without title

# %%
qplot(TotalRebounds,TotalPoints,data=NBA1920,facets=.~Position,binwidth=100)
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth”
# plot without title
